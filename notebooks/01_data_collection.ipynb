# %% [markdown]
# # 01 - Data Collection
# Run polling script for orderbooks and ticker data.

# %%
# !python ../scripts/poll_orderbooks.py --output-dir ../data/raw --once

# %%
# !python ../scripts/poll_orderbooks.py --output-dir ../data/raw --backfill-klines --once
